# %%
import glob
from pathlib import Path
import date_extractor_utils

# %%
p=Path("./Receipts/")
dic={}
for images in p.glob("*.jpeg"):
    full_image_path="./"+str(images)
    print(full_image_path)
    pred=date_extractor_utils.predictions(full_image_path)
    dic[full_image_path]=pred
# Out:
# ./Receipts/32b4d880.jpeg
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# DATES: []
# ./Receipts/cce28d60.jpeg
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# DATES: []
# ./Receipts/317fb684.jpeg
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# adaptive_thresh_list[]
# DATES: []
# ./Receipts/fb835913.jpeg
# ...

# %%
vals=dic.values()

# %% [markdown]
# # TOTAL DATES EXTRACTED

# %%
count=0
li=[1 for i in vals if i!="CAN'T FIND DATE OR THE PHOTO IS NOT CLEAR"]

# %%
len(li)
# Out:
# 287

# %% [markdown]
# # TOTAL IMAGES

# %%
print(len(vals))
# Out:
# 595

# %% [markdown]
# # APPROX ACCURACY:

# %%
acc=(287/595)*100
print(acc)
# Out:
# 48.23529411764706

# %% [markdown]
# # THE SCANNER WAS ABLE TO EXTRACT DATE FROM 50 PERCENT OF LOW IMPROPER CAPTURED IMAGES
